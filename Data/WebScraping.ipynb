# %% [markdown]
# # Web Scaraping (iHerb)

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
import csv
from itertools import zip_longest
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conda install -c conda-forge selenium
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # startup the scraping

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver=webdriver.Chrome(ChromeDriverManager().install())

#driver.get('https://www.iherb.com/c/face-moisturizers-creams')
sport_url = "https://au.iherb.com/c/face-moisturizers-creams?p=1"
r = requests.get(sport_url )
html = r.text
soup = BeautifulSoup(html, 'lxml')
driver.get(sport_url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/User/.wdm/drivers/chromedriver/mac64/96.0.4664.45]

# %%
product_title=[]
Price=[]
Rating=[]
Review=[]
Size=[]
page_num=0
brands=[]

# %%
  
while page_num <= 43 :
    result = requests.get(f"https://au.iherb.com/c/face-moisturizers-creams?p={page_num}")
    src=result.content
    soup = BeautifulSoup(src,"lxml")

     
    for item in soup.findAll('div',class_='product-title'):
        product_title.append(item.text.replace('\n',''))


    for item in soup.findAll('div',class_='rating'):
        Review.append(item.text.replace('\n',''))


    for item in soup.findAll('div',class_='product-price-top'):
        Price.append(item.text.replace('\n',''))


    for item in soup.findAll('a',class_='https://au.iherb.com/pr/mason-natural-collagen-premium-skin-'):
        link.append(item.text)
        
  
    for i in soup.find_all('a', {"class":"stars"}):
        Rating.append(i['title'])

         
    page_num+=1
    print("page switched")
# Out:
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched
# page switched

# %%
Rating
# Out:
# ['4.5/5 - 965 Reviews',
#  '4.5/5 - 1562 Reviews',
#  '4.5/5 - 1167 Reviews',
#  '4.4/5 - 1356 Reviews',
#  '4.5/5 - 20523 Reviews',
#  '4.4/5 - 40789 Reviews',
#  '4.5/5 - 19908 Reviews',
#  '4.6/5 - 48426 Reviews',
#  '4.5/5 - 12928 Reviews',
#  '4.4/5 - 12629 Reviews',
#  '4.4/5 - 7943 Reviews',
#  '4.6/5 - 48426 Reviews',
#  '4.7/5 - 3432 Reviews',
#  '4.4/5 - 5955 Reviews',
#  '4.4/5 - 13493 Reviews',
#  '4.6/5 - 3016 Reviews',
#  '4.4/5 - 5667 Reviews',
#  '4.5/5 - 2410 Reviews',
#  '4.5/5 - 2883 Reviews',
#  '4.4/5 - 2679 Reviews',
#  '4.2/5 - 6080 Reviews',
#  '4.7/5 - 1887 Reviews',
#  '4.4/5 - 3887 Reviews',
#  '4.1/5 - 3839 Reviews',
#  '4.4/5 - 1820 Reviews',
#  '4.5/5 - 8152 Reviews',
#  '4.4/5 - 1533 Reviews',
#  '4.5/5 - 9673 Reviews',
#  '4.7/5 - 1844 Reviews',
#  '4.3/5 - 2470 Reviews',
#  '4.5/5 - 1700 Reviews',
#  '4.6/5 - 3093 Reviews',
#  '4.4/5 - 2353 Reviews',
#  '4.7/5 - 1339 Reviews',
#  '4.6/5 - 2373 Reviews',
#  '4.7/5 - 3456 Reviews',
# ...

# %% [markdown]
# # Load data in file

# %%
file_list = [product_title,Price,Review,Rating]
exported = zip_longest(*file_list)
# 7th step create csv file and fill it with values
with open("/Users/User/Desktop/Project2/face_moisturizers_creams.csv", "w") as myfile:
    wr = csv.writer(myfile)
    wr.writerow(["product_title", "Price","Review","Rating"])
    wr.writerows(exported)

# %%
with open("face_moisturizers_creams.csv","r") as file:
    records=[]
    for line in file:
        records.append(line.strip())

# %% [markdown]
# # Dataframe

# %%
df=pd.read_csv("/Users/User/Desktop/Project2/face_moisturizers_creams.csv")
df.shape
# Out:
# (1010, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_title  1010 non-null   object
#  1   Price          1010 non-null   object
#  2   Review         948 non-null    float64
#  3   Rating         948 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 31.7+ KB

# %%
df.head(20)
# Out:
#                                         product_title  \
# 0   PrescriptSkin, Retinol Night Cream, 1.55 oz (4...
# 1   PrescriptSkin, Vitamin C Moisturizer, Enhanced...
# 2      PrescriptSkin, Stem Cell Cream, 2.25 oz (64 g)
# 3   Sympli Beautiful, All Day Hydration Cream, 2 o...
# 4   Eucerin, Q10 Anti-Wrinkle Face Cream, 1.7 oz (...
# 5   Life-flo, Pure Rosehip Seed Oil, Skin Care, 1 ...
# 6   Mason Natural, Collagen Premium Skin Cream, 2 ...
# 7   Now Foods, Solutions, Sweet Almond Oil, 16 fl ...
# 8   Acure, The Essentials, Moroccan Argan Oil, 1 f...
# 9   Queen Helene, Cocoa Butter Face + Body Creme, ...
# 10  Life-flo, Retinol A 1%, Advanced Revitalizatio...
# 11  Now Foods, Solutions, Sweet Almond Oil, 4 fl o...
# 12  Cetaphil, Moisturizing Cream, Very Dry, Sensit...
# 13         Yeouth, Retinol Eye Cream, 1 fl oz (30 ml)
# 14  Heritage Store, Rosewater & Glycerin, Hydratin...
# 15  Acure, Radically Rejuvenating, Rose Argan Oil,...
# ...
